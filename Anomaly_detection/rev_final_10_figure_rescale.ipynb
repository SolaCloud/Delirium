# %%
from PIL import Image

img = Image.open("figures_to_deal/figure3_anomaly_ForestIsolation_30a32.png")

# Resize while keeping aspect ratio
img.thumbnail((1200, 1200))

img.save("figures_to_deal/figure3_anomaly_ForestIsolation_30a32_rescale.png")

# %%
from PIL import Image

img = Image.open("figures_to_deal/figure4_stripplot_importance.png")

# Resize while keeping aspect ratio
img.thumbnail((1200, 1200))

img.save("figures_to_deal/figure4_stripplot_importance_rescale.png")

# %%
from PIL import Image

img = Image.open("figures_to_deal/figure5_corr_compare.png")

# Resize while keeping aspect ratio
img.thumbnail((1200, 1200))

img.save("figures_to_deal/figure5_corr_compare_rescale.png")
